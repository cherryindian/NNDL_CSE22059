# %%
 from sklearn.datasets import load_digits
from sklearn.linear_model import Perceptron
import math
import numpy as np
import pandas as pd

# %%
X, y = load_digits(return_X_y=True)
clf = Perceptron(tol=1e-3, random_state=0)
clf.fit(X, y)
# Out:
# Perceptron()

# %%
def summation_unit(inputs, weights):
    return sum(i * w for i, w in zip(inputs, weights))

# %%
def step_act(x):
    return 1 if x >= 0 else 0

def bipolar_step_act(x):
    return 1 if x >= 0 else -1

def sigmoid_act(x):
    return 1 / (1 + np.exp(-x))

def tanh_act(x):
    return math.tanh(x)

def relu_act(x):
    return max(0, x)

def leaky_relu_act(x, alpha=0.01):
    return x if x > 0 else alpha * x

# %%
def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

# %%
def act(val,n):
    if n == 0:
        return step_act(val)
    elif n == 1:
        return bipolar_step_act(val)
    elif n == 2:
        return sigmoid_act(val)
    elif n == 3:
        return tanh_act(val)
    elif n == 4:
        return relu_act(val)
    elif n == 5:
        return leaky_relu_act(val)
    else:
        return None

# %%
b = 10
W1 = 0.2
W2 = -0.75
alpha = 0.05
 
def percept(b,w1,w2,alpha,X,y,activation):
    itera = 0
    y_output = [0]*len(X)
    y_accepted = [False]*len(X)
    i = 0
    while not (all(y_accepted)):
        itera+=1
        y_output[i] = act(b + X[i][0] * w1 + X[i][1] * w2,activation)
        if y_output[i] == y[i]:
            y_accepted[i] = True
        else:
            b=b+alpha*(y[i]-y_output[i])
            w1=w1+alpha*(y[i]-y_output[i])*X[i][0]
            w2=w2+alpha*(y[i]-y_output[i])*X[i][1]
            y_accepted[i] = False
        i = (i+1)%len(X)
        if itera > 10000000:
            break
    return b,w1,w2,itera
X = [[0,0],[0,1],[1,0],[1,1]]
y = [0,0,0,1]
print(percept(1,1,1,1,X,y,0))
# Out:
# (-2, 2, 1, 18)

# %%
print(percept(1,1,1,1,X,y,1))
print(percept(1,1,1,1,X,y,2))
print(percept(1,1,1,1,X,y,3))
print(percept(1,1,1,1,X,y,4))
print(percept(1,1,1,1,X,y,5))
# Out:
# (0, 3, 3, 10000001)
# (-39.0306477959361, 25.908278515434, 25.90827601545946, 10000001)
# (-0.33400969799712876, 2.305269448740998, 1.4866444223676283, 10000001)
# (-2, 2, 1, 18)
# (-1.9969999176308595, 2.2326745599155333, 2.083065415955652, 10000001)

# %%
print(percept(1,1,1,0.1,X,y,0))
print(percept(1,1,1,0.2,X,y,0))
print(percept(1,1,1,0.3,X,y,0))
print(percept(1,1,1,0.4,X,y,0))
print(percept(1,1,1,0.5,X,y,0))
print(percept(1,1,1,0.6,X,y,0))
print(percept(1,1,1,0.7,X,y,0))
print(percept(1,1,1,0.8,X,y,0))
print(percept(1,1,1,0.9,X,y,0))
print(percept(1,1,1,1,X,y,0))
# Out:
# (-0.5999999999999999, 0.40000000000000013, 0.40000000000000013, 27)
# (-0.6, 0.4000000000000001, 0.4000000000000001, 15)
# (-0.8, 0.7, 0.39999999999999997, 14)
# (-0.6000000000000001, 0.6, 0.19999999999999996, 10)
# (-0.5, 0.5, 0.5, 7)
# (-0.7999999999999999, 0.4, 0.4, 7)
# (-1.0999999999999999, 1.0, 0.30000000000000004, 10)
# (-2.2, 1.8, 1.0, 22)
# (-2.6, 1.9, 0.9999999999999999, 22)
# (-2, 2, 1, 18)

# %%
X = [[0,0],[0,1],[1,0],[1,1]]
y = [0,1,1,0]
print(percept(1,1,1,1,X,y,0))
print(percept(1,1,1,1,X,y,1))
print(percept(1,1,1,1,X,y,2))
print(percept(1,1,1,1,X,y,3))
print(percept(1,1,1,1,X,y,4))
print(percept(1,1,1,1,X,y,5))
# Out:
# (0, -1, 0, 10000001)
# (0, -1, -1, 10000001)
# (-4.440892098500626e-16, -1.3180921368148129, -0.6590460684074065, 10000001)
# (1.0000195160809664, -1.9223627192134032, -0.9611813596067013, 10000001)
# (0, -2, -1, 10000001)
# (0.0, -2.020202020202003, -1.0101010101010268, 10000001)

# %%
df = pd.read_excel("C:\\Users\\srich\\Desktop\\project_newday\\year3\\ML\\Lab Session Data.xlsx")
df
# Out:
#   Customer  Candies (#)  Mangoes (Kg)  Milk Packets (#)  Payment (Rs)  \
# 0      C_1           20             6                 2           386
# 1      C_2           16             3                 6           289
# 2      C_3           27             6                 2           393
# 3      C_4           19             1                 2           110
# 4      C_5           24             4                 2           280
# 5      C_6           22             1                 5           167
# 6      C_7           15             4                 2           271
# 7      C_8           18             4                 2           274
# 8      C_9           21             1                 4           148
# 9     C_10           16             2                 4           198
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# ...

# %%
df.rename(columns={"Unnamed: 5": "High Value Tx"}, inplace=True)
tax = []
for i in ["Yes"]*3+["No","Yes","No"]+["Yes"]*2+["No"]*2:
    tax.append(i)
df.loc[:, "High Value Tx"] = tax
df
# Out:
#   Customer  Candies (#)  Mangoes (Kg)  Milk Packets (#)  Payment (Rs)  \
# 0      C_1           20             6                 2           386
# 1      C_2           16             3                 6           289
# 2      C_3           27             6                 2           393
# 3      C_4           19             1                 2           110
# 4      C_5           24             4                 2           280
# 5      C_6           22             1                 5           167
# 6      C_7           15             4                 2           271
# 7      C_8           18             4                 2           274
# 8      C_9           21             1                 4           148
# 9     C_10           16             2                 4           198
#
#   High Value Tx  High Value Tx(number)  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0           Yes                    NaN         NaN         NaN         NaN
# ...

# %%
df.rename(columns={"Unnamed: 6": "High Value Tx(number)"}, inplace=True)
tax = ( int(1) if i == "Yes" else int(0) for i in df["High Value Tx"])
df.loc[:, "High Value Tx(number)"] = list(tax)
df
# Out:
#   Customer  Candies (#)  Mangoes (Kg)  Milk Packets (#)  Payment (Rs)  \
# 0      C_1           20             6                 2           386
# 1      C_2           16             3                 6           289
# 2      C_3           27             6                 2           393
# 3      C_4           19             1                 2           110
# 4      C_5           24             4                 2           280
# 5      C_6           22             1                 5           167
# 6      C_7           15             4                 2           271
# 7      C_8           18             4                 2           274
# 8      C_9           21             1                 4           148
# 9     C_10           16             2                 4           198
#
#   High Value Tx  High Value Tx(number)  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0           Yes                    1.0         NaN         NaN         NaN
# ...

# %%
X = df.iloc[:, 1:5].values
y = []
for i in list(df.iloc[:, 6].values):
    y.append(int(i))
b = 0.0
w = np.zeros(X.shape[1])
alpha = 0.01  

def perc(X, y, alpha, epochs):
    global b
    global w
    for epoch in range(epochs):
        for i in range(len(X)):
            linear_output = np.dot(X[i], w) + b
            y_pred = sigmoid_act(linear_output)
            
            error = y[i] - y_pred
            if error != 0:
                b = b + alpha * error
                w = w + alpha * error * X[i]
    return w, b

w, b = perc(X, y, alpha, epochs=250)

print("Trained Weights:", w)
print("Trained Bias:", b)

def predict(X):
    global b
    global w
    predictions = []
    for i in range(len(X)):
        linear_output = np.dot(X[i], w) + b
        y_pred = sigmoid_act(linear_output)
        predictions.append(1 if y_pred >= 0.5 else 0)
    return predictions

p = predict(X)
print("Predictions:", p)
print("Actual Labels:", y)
# Out:
# Trained Weights: [-44.15270658   5.32965908 -13.65477017   3.19268009]
# Trained Bias: -2.499060896549578
# Predictions: [1, 1, 1, 0, 0, 0, 1, 1, 0, 0]
# Actual Labels: [1, 1, 1, 0, 1, 0, 1, 1, 0, 0]
# C:\Users\srich\AppData\Local\Temp\ipykernel_218736\2218288425.py:8: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))

# %%
clf = Perceptron(tol=1e-3, random_state=0)
clf.fit(X, y)
# Out:
# Perceptron()

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y, clf.predict(X)))
clf.predict(X)
# Out:
# array([1, 1, 1, 0, 1, 0, 1, 1, 0, 1])

# %%
# Derivative of the Sigmoid function (for backpropagation)
def sigmoid_derivative(x):
    return x * (1 - x)

# %%
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])  # Inputs
y = np.array([[0], [0], [0], [1]])  # Outputs (AND gate)

# Initialize weights and biases randomly
np.random.seed(42)
weights_input_hidden = np.random.rand(2, 2)  
weights_hidden_output = np.random.rand(2, 1) 
bias_hidden = np.random.rand(1, 2)  
bias_output = np.random.rand(1, 1)  

# Learning rate
alpha = 0.05
final_output = None

epochs = 10000
for epoch in range(epochs):
    #forward pass
    hidden_input = np.dot(X, weights_input_hidden) + bias_hidden  # Input to hidden layer
    hidden_output = sigmoid_act(hidden_input)  # Output from hidden layer
    
    final_input = np.dot(hidden_output, weights_hidden_output) + bias_output  # Input to output layer
    final_output = sigmoid_act(final_input)  # Final output (prediction)
    
    #mean squared error
    error = y - final_output
    
    # Backpropagation
    # Output layer error gradient
    d_output = error * sigmoid_derivative(final_output)
    
    # Hidden layer error gradient
    hidden_error = d_output.dot(weights_hidden_output.T)
    d_hidden = hidden_error * sigmoid_derivative(hidden_output)
    
    # Update weights and biases
    weights_hidden_output += hidden_output.T.dot(d_output) * alpha
    weights_input_hidden += X.T.dot(d_hidden) * alpha
    bias_output += np.sum(d_output, axis=0, keepdims=True) * alpha
    bias_hidden += np.sum(d_hidden, axis=0, keepdims=True) * alpha

# After training, let's see the final output
print("Final output after training:")
print(final_output)

# Test predictions after training
def predict(X):
    hidden_input = np.dot(X, weights_input_hidden) + bias_hidden
    hidden_output = sigmoid_act(hidden_input)
    final_input = np.dot(hidden_output, weights_hidden_output) + bias_output
    return sigmoid_act(final_input)

# Predictions for the AND gate
predictions = predict(X)
print("\nPredictions for AND gate logic (rounded):")
print(np.round(predictions))  # Rounding the output for binary classification
# Out:
# Final output after training:
# [[0.01774472]
#  [0.05862773]
#  [0.05836721]
#  [0.92165943]]
#
# Predictions for AND gate logic (rounded):
# [[0.]
#  [0.]
#  [0.]
#  [1.]]
